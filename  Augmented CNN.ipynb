# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import argparse
import random
import os
import cv2
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, roc_auc_score
from mlxtend.plotting import plot_confusion_matrix

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19,VGG16
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
 
print("TF version:", tf.__version__)
print("TF Hub version:", hub.__version__)
print("GPU", "available (True)" if tf.config.list_physical_devices("GPU") else "not available :(")
# Out:
# TF version: 2.8.0
# TF Hub version: 0.12.0
# GPU available (True)

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
fid = drive.ListFile({'q':"title='imagecovid.zip'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('imagecovid.zip')

# %%
f.keys()
# Out:
# dict_keys(['id', 'kind', 'etag', 'selfLink', 'webContentLink', 'alternateLink', 'embedLink', 'iconLink', 'title', 'mimeType', 'labels', 'copyRequiresWriterPermission', 'createdDate', 'modifiedDate', 'modifiedByMeDate', 'lastViewedByMeDate', 'markedViewedByMeDate', 'version', 'parents', 'downloadUrl', 'userPermission', 'originalFilename', 'fileExtension', 'md5Checksum', 'fileSize', 'quotaBytesUsed', 'ownerNames', 'owners', 'lastModifyingUserName', 'lastModifyingUser', 'capabilities', 'editable', 'copyable', 'writersCanShare', 'shared', 'explicitlyTrashed', 'appDataContents', 'headRevisionId', 'spaces'])

# %%
# !unzip imagecovid.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: imagecovid/Normal/Normal-1929.png
#   inflating: imagecovid/Normal/Normal-193.png
#   inflating: imagecovid/Normal/Normal-1930.png
#   inflating: imagecovid/Normal/Normal-1931.png
#   inflating: imagecovid/Normal/Normal-1932.png
#   inflating: imagecovid/Normal/Normal-1933.png
#   inflating: imagecovid/Normal/Normal-1934.png
#   inflating: imagecovid/Normal/Normal-1935.png
#   inflating: imagecovid/Normal/Normal-1936.png
#   inflating: imagecovid/Normal/Normal-1937.png
#   inflating: imagecovid/Normal/Normal-1938.png
#   inflating: imagecovid/Normal/Normal-1939.png
#   inflating: imagecovid/Normal/Normal-194.png
#   inflating: imagecovid/Normal/Normal-1940.png
#   inflating: imagecovid/Normal/Normal-1941.png
#   inflating: imagecovid/Normal/Normal-1942.png
#   inflating: imagecovid/Normal/Normal-1943.png
#   inflating: imagecovid/Normal/Normal-1944.png
#   inflating: imagecovid/Normal/Normal-1945.png
#   inflating: imagecovid/Normal/Normal-1946.png
#   inflating: imagecovid/Normal/Normal-1947.png
#   inflating: imagecovid/Normal/Normal-1948.png
#   inflating: imagecovid/Normal/Normal-1949.png
#   inflating: imagecovid/Normal/Normal-195.png
#   inflating: imagecovid/Normal/Normal-1950.png
#   inflating: imagecovid/Normal/Normal-1951.png
#   inflating: imagecovid/Normal/Normal-1952.png
#   inflating: imagecovid/Normal/Normal-1953.png
#   inflating: imagecovid/Normal/Normal-1954.png
#   inflating: imagecovid/Normal/Normal-1955.png
#   inflating: imagecovid/Normal/Normal-1956.png
#   inflating: imagecovid/Normal/Normal-1957.png
#   inflating: imagecovid/Normal/Normal-1958.png
#   inflating: imagecovid/Normal/Normal-1959.png
#   inflating: imagecovid/Normal/Normal-196.png
#   inflating: imagecovid/Normal/Normal-1960.png
#   inflating: imagecovid/Normal/Normal-1961.png
#   inflating: imagecovid/Normal/Normal-1962.png
#   inflating: imagecovid/Normal/Normal-1963.png
#   inflating: imagecovid/Normal/Normal-1964.png
#   inflating: imagecovid/Normal/Normal-1965.png
#   inflating: imagecovid/Normal/Normal-1966.png
#   inflating: imagecovid/Pneomonia/person982_virus_1658.jpeg
#   inflating: imagecovid/Pneomonia/person983_bacteria_2910.jpeg
#   inflating: imagecovid/Pneomonia/person983_virus_1660.jpeg
#   inflating: imagecovid/Pneomonia/person984_bacteria_2911.jpeg
#   inflating: imagecovid/Pneomonia/person985_bacteria_2912.jpeg
#   inflating: imagecovid/Pneomonia/person986_bacteria_2913.jpeg
#   inflating: imagecovid/Pneomonia/person987_bacteria_2914.jpeg
#   inflating: imagecovid/Pneomonia/person988_bacteria_2915.jpeg
#   inflating: imagecovid/Pneomonia/person988_virus_1666.jpeg
#   inflating: imagecovid/Pneomonia/person989_virus_1667.jpeg
#   inflating: imagecovid/Pneomonia/person99_virus_183.jpeg
#   inflating: imagecovid/Pneomonia/person990_bacteria_2917.jpeg
#   inflating: imagecovid/Pneomonia/person991_bacteria_2918.jpeg
#   inflating: imagecovid/Pneomonia/person991_virus_1669.jpeg
#   inflating: imagecovid/Pneomonia/person992_bacteria_2919.jpeg
#   inflating: imagecovid/Pneomonia/person992_bacteria_2920.jpeg
#   inflating: imagecovid/Pneomonia/person992_virus_1670.jpeg
#   inflating: imagecovid/Pneomonia/person993_bacteria_2921.jpeg
#   inflating: imagecovid/Pneomonia/person993_virus_1671.jpeg
#   inflating: imagecovid/Pneomonia/person994_bacteria_2922.jpeg
#   inflating: imagecovid/Pneomonia/person994_virus_1672.jpeg
#   inflating: imagecovid/Pneomonia/person995_bacteria_2923.jpeg
#   inflating: imagecovid/Pneomonia/person995_virus_1676.jpeg
#   inflating: imagecovid/Pneomonia/person996_bacteria_2924.jpeg
#   inflating: imagecovid/Pneomonia/person996_virus_1677.jpeg
#   inflating: imagecovid/Pneomonia/person997_bacteria_2926.jpeg
#   inflating: imagecovid/Pneomonia/person997_virus_1678.jpeg
#   inflating: imagecovid/Pneomonia/person998_bacteria_2927.jpeg
#   inflating: imagecovid/Pneomonia/person998_bacteria_2928.jpeg

# %%
PATH= '/content/imagecovid'

# %%
COVID_PATH = '/content/imagecovid/Covid/'
NORMAL_PATH = '/content/imagecovid/Normal/'
PNEUMONIA_PATH = '/content/imagecovid/Pneomonia'

# %%
import pandas as pd
import numpy as np
import os
from glob import glob
import random
import matplotlib.pylab as plt
import seaborn as sns
pd.set_option('display.max_colwidth', None)

# %%
#Data Preprocessing
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from glob import glob
from PIL import Image
import os
import random
import cv2

# %%
#Model
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model,load_model
from tensorflow.keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPooling2D,MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical # convert to one-hot-encoding
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping,ModelCheckpoint
from tensorflow.keras.metrics import PrecisionAtRecall,Recall

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# %%
from numpy.random import seed
seed(0)

# %%
def img_preprocessing(image_path):
    img = cv2.imread(image_path, 0)
    org_img = img.copy()
    brightest = np.max(img)
    darkest = np.min(img)
    T = darkest + 0.9*(brightest - darkest)
    thre_img = cv2.threshold(img, T, 255, cv2.THRESH_BINARY)
    thre_img = thre_img[1]
    kernel = np.ones((5, 5), np.uint8)
    cleaned = cv2.erode(thre_img, kernel, iterations = 5)
    cleaned = cv2.dilate(cleaned, kernel, iterations = 5)
    cleaned = cleaned//255
    img = img * cleaned
    img = org_img - img
    dim = (224, 224)
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    B = cv2.bilateralFilter(img, 9, 75, 75)
    R = cv2.equalizeHist(img)
    new_img = cv2.merge((B, img, R))
    return new_img

# %%
img = img_preprocessing(COVID_PATH + '/COVID-1.png')
plt.imshow(img)

# %%
base_dir = 'base_dir'
os.mkdir(base_dir)
train_dir = os.path.join(base_dir, 'train_dir')
os.mkdir(train_dir)
val_dir = os.path.join(base_dir, 'val_dir')
os.mkdir(val_dir)
test_dir = os.path.join(base_dir, 'test_dir')
os.mkdir(test_dir)
Normal = os.path.join(train_dir, 'Normal')
os.mkdir(Normal)
COVID = os.path.join(train_dir, 'COVID')
os.mkdir(COVID)
Viral_Pneumonia = os.path.join(train_dir, 'Viral_Pneumonia')
os.mkdir(Viral_Pneumonia)
Normal = os.path.join(val_dir, 'Normal')
os.mkdir(Normal)
COVID = os.path.join(val_dir, 'COVID')
os.mkdir(COVID)
Viral_Pneumonia = os.path.join(val_dir, 'Viral_Pneumonia')
os.mkdir(Viral_Pneumonia)
Normal = os.path.join(test_dir, 'Normal')
os.mkdir(Normal)
COVID = os.path.join(test_dir, 'COVID')
os.mkdir(COVID)
Viral_Pneumonia = os.path.join(test_dir, 'Viral_Pneumonia')
os.mkdir(Viral_Pneumonia)

# %%
import numpy as np
from sklearn.utils import shuffle

# %%
folder_1 = os.listdir(COVID_PATH)
folder_1 = shuffle(folder_1)
folder_2 = os.listdir(NORMAL_PATH)
folder_2 = shuffle(folder_2)
folder_3 = os.listdir(PNEUMONIA_PATH)
folder_3 = shuffle(folder_3)

# %%
covid_data = pd.DataFrame(folder_1, columns = ['FILE NAME'])
normal_data = pd.DataFrame(folder_2, columns = ['FILE NAME'])
pneumonia_data = pd.DataFrame(folder_3, columns = ['FILE NAME'])
covid_data['Target'] = 'COVID'
normal_data['Target'] = 'Normal'
pneumonia_data['Target'] = 'Viral_Pneumonia'
covid_data['Labels'] = '0'
normal_data['Labels'] = '1'
pneumonia_data['Labels'] = '2'
data = pd.concat([covid_data, normal_data, pneumonia_data], axis = 0, sort = False)
data
# Out:
#                          FILE NAME           Target Labels
# 0                    COVID-314.png            COVID      0
# 1                    COVID-504.png            COVID      0
# 2                   COVID-1686.png            COVID      0
# 3                   COVID-1834.png            COVID      0
# 4                    COVID-387.png            COVID      0
# ...                            ...              ...    ...
# 3011      person447_virus_921.jpeg  Viral_Pneumonia      2
# 3012     person503_virus_1013.jpeg  Viral_Pneumonia      2
# 3013    person1290_virus_2215.jpeg  Viral_Pneumonia      2
# 3014     person641_virus_1222.jpeg  Viral_Pneumonia      2
# 3015  person977_bacteria_2902.jpeg  Viral_Pneumonia      2
#
# [9048 rows x 3 columns]

# %%
covid_data = pd.DataFrame(folder_1, columns = ['FILE NAME'])
normal_data = pd.DataFrame(folder_2, columns = ['FILE NAME'])
pneumonia_data = pd.DataFrame(folder_3, columns = ['FILE NAME'])
covid_data['Target'] = 'COVID'
normal_data['Target'] = 'Normal'
pneumonia_data['Target'] = 'Viral_Pneumonia'
covid_data['Labels'] = '0'
normal_data['Labels'] = '1'
pneumonia_data['Labels'] = '2'
data = pd.concat([covid_data, normal_data, pneumonia_data], axis = 0, sort = False)
data
# Out:
#                          FILE NAME           Target Labels
# 0                    COVID-314.png            COVID      0
# 1                    COVID-504.png            COVID      0
# 2                   COVID-1686.png            COVID      0
# 3                   COVID-1834.png            COVID      0
# 4                    COVID-387.png            COVID      0
# ...                            ...              ...    ...
# 3011      person447_virus_921.jpeg  Viral_Pneumonia      2
# 3012     person503_virus_1013.jpeg  Viral_Pneumonia      2
# 3013    person1290_virus_2215.jpeg  Viral_Pneumonia      2
# 3014     person641_virus_1222.jpeg  Viral_Pneumonia      2
# 3015  person977_bacteria_2902.jpeg  Viral_Pneumonia      2
#
# [9048 rows x 3 columns]

# %%
y1 = data['Labels']
df_train, df_val_test = train_test_split(data, test_size=0.3, random_state=101, stratify = y1)
y2 = df_val_test['Labels']
df_val, df_test = train_test_split(df_val_test, test_size=0.5, random_state=101, stratify = y2)
print(df_train.shape)
print(df_val.shape)
print(df_test.shape)
df_train[100:120]
# Out:
# (6333, 3)
# (1357, 3)
# (1358, 3)
#                          FILE NAME           Target Labels
# 651                 COVID-1810.png            COVID      0
# 1602                COVID-2765.png            COVID      0
# 2954               Normal-2333.png           Normal      1
# 800                Normal-1135.png           Normal      1
# 1569                COVID-1420.png            COVID      0
# 2021    person30_bacteria_157.jpeg  Viral_Pneumonia      2
# 2561                COVID-1611.png            COVID      0
# 2902                Normal-357.png           Normal      1
# 86                 Normal-1976.png           Normal      1
# 2775                 COVID-512.png            COVID      0
# 1185                COVID-2611.png            COVID      0
# 2948               Normal-2872.png           Normal      1
# 2169                COVID-1090.png            COVID      0
# 3004               Normal-2678.png           Normal      1
# 215                 COVID-2636.png            COVID      0
# 2836    person1270_virus_2163.jpeg  Viral_Pneumonia      2
# 388   person406_bacteria_1818.jpeg  Viral_Pneumonia      2
# 1137                COVID-2538.png            COVID      0
# 306                  COVID-360.png            COVID      0
# 2661               Normal-2054.png           Normal      1

# %%
data.set_index('FILE NAME', inplace = True)
data
# Out:
#                                        Target Labels
# FILE NAME
# COVID-314.png                           COVID      0
# COVID-504.png                           COVID      0
# COVID-1686.png                          COVID      0
# COVID-1834.png                          COVID      0
# COVID-387.png                           COVID      0
# ...                                       ...    ...
# person447_virus_921.jpeg      Viral_Pneumonia      2
# person503_virus_1013.jpeg     Viral_Pneumonia      2
# person1290_virus_2215.jpeg    Viral_Pneumonia      2
# person641_virus_1222.jpeg     Viral_Pneumonia      2
# person977_bacteria_2902.jpeg  Viral_Pneumonia      2
#
# [9048 rows x 2 columns]

# %%
data.tail()
# Out:
#                                        Target Labels
# FILE NAME
# person447_virus_921.jpeg      Viral_Pneumonia      2
# person503_virus_1013.jpeg     Viral_Pneumonia      2
# person1290_virus_2215.jpeg    Viral_Pneumonia      2
# person641_virus_1222.jpeg     Viral_Pneumonia      2
# person977_bacteria_2902.jpeg  Viral_Pneumonia      2

# %%
# Get a list of train and val images
train_list = list(df_train['FILE NAME'])
val_list = list(df_val['FILE NAME'])
test_list = list(df_val['FILE NAME'])

# %%
# Transfer the train images

for image in train_list:
    fname = image
    label = data.loc[image,'Target']
    if fname in folder_1:
        src = os.path.join(COVID_PATH, fname)
        dst = os.path.join(train_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)

for image in val_list:
    fname = image
    label = data.loc[image,'Target']
    if fname in folder_1:
        src = os.path.join(COVID_PATH, fname)
        dst = os.path.join(val_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)
        
for image in test_list:
    fname = image 
    label = data.loc[image,'Target']
    if fname in folder_1:
        src = os.path.join(COVID_PATH, fname)
        dst = os.path.join(test_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)

# %%
for image in train_list:

    fname = image
    label = data.loc[image,'Target']
    if fname in folder_2:
        src = os.path.join(NORMAL_PATH, fname)
        dst = os.path.join(train_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)

for image in val_list:
    fname = image
    label = data.loc[image,'Target']
    if fname in folder_2:
        src = os.path.join(NORMAL_PATH, fname)
        dst = os.path.join(val_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)
        
for image in test_list:
    fname = image 
    label = data.loc[image,'Target']
    if fname in folder_2:
        src = os.path.join(NORMAL_PATH, fname)
        dst = os.path.join(test_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)

# %%
for image in train_list:
    fname = image
    label = data.loc[image,'Target']
    if fname in folder_3:
        src = os.path.join(PNEUMONIA_PATH, fname)
        dst = os.path.join(train_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)

for image in val_list:
    fname = image 
    label = data.loc[image,'Target']
    if fname in folder_3:
        src = os.path.join(PNEUMONIA_PATH, fname)
        dst = os.path.join(val_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)
        
for image in test_list:
    fname = image 
    label = data.loc[image,'Target']
    if fname in folder_3:
        src = os.path.join(PNEUMONIA_PATH, fname)
        dst = os.path.join(test_dir, label, fname)
        image = img_preprocessing(src)
        cv2.imwrite(dst, image)

# %%
print(len(os.listdir('base_dir/train_dir/Normal')))
print(len(os.listdir('base_dir/val_dir/Normal')))
print(len(os.listdir('base_dir/train_dir/COVID')))
print(len(os.listdir('base_dir/val_dir/COVID')))
print(len(os.listdir('base_dir/train_dir/Viral_Pneumonia')))
print(len(os.listdir('base_dir/val_dir/Viral_Pneumonia')))
# Out:
# 2111
# 452
# 2111
# 452
# 2111
# 453

# %%
###changed number of agumented data 

NUM_AUG_IMAGES_WANTED = 3000

IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import shutil

# %%
class_list = ['COVID', 'Normal', 'Viral_Pneumonia']

for item in class_list:
    aug_dir = 'aug_dir'
    os.mkdir(aug_dir)
    img_dir = os.path.join(aug_dir, 'img_dir')
    os.mkdir(img_dir)
    img_class = item
    img_list = os.listdir('./base_dir/train_dir/' + img_class)
    for fname in img_list:
            src = os.path.join('./base_dir/train_dir/' + img_class, fname)
            dst = os.path.join(img_dir, fname)
            shutil.copyfile(src, dst)
    path = aug_dir
    save_path = './base_dir/train_dir/' + img_class

    datagen = ImageDataGenerator(
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        fill_mode='nearest')

    batch_size = 32

    aug_datagen = datagen.flow_from_directory(path,save_to_dir=save_path,save_format='png',target_size=(IMAGE_HEIGHT,IMAGE_WIDTH),batch_size=batch_size)
    num_files = len(os.listdir(img_dir))
    num_batches = int(np.ceil((NUM_AUG_IMAGES_WANTED-num_files)/batch_size))

    for i in range(0,num_batches):
        imgs, labels = next(aug_datagen)
    shutil.rmtree('aug_dir')
# Out:
# Found 2111 images belonging to 1 classes.
# Found 2111 images belonging to 1 classes.
# Found 2111 images belonging to 1 classes.

# %%
print(len(os.listdir('base_dir/train_dir/Normal')))
print(len(os.listdir('base_dir/val_dir/Normal')))
print(len(os.listdir('base_dir/train_dir/COVID')))
print(len(os.listdir('base_dir/val_dir/COVID')))
print(len(os.listdir('base_dir/train_dir/Viral_Pneumonia')))
print(len(os.listdir('base_dir/val_dir/Viral_Pneumonia')))
# Out:
# 3007
# 452
# 3007
# 452
# 3007
# 453

# %%
train_path = 'base_dir/train_dir'
valid_path = 'base_dir/val_dir'
test_path = 'base_dir/test_dir'

# %%
datagen = ImageDataGenerator(rescale=1.0/255)

train_gen = datagen.flow_from_directory(train_path,
                                        target_size=(IMAGE_HEIGHT,IMAGE_WIDTH),
                                        batch_size=32,
                                        class_mode='categorical')

val_gen = datagen.flow_from_directory(valid_path,
                                        target_size=(IMAGE_HEIGHT,IMAGE_WIDTH),
                                        batch_size=32,
                                        class_mode='categorical')

test_gen = datagen.flow_from_directory(test_path,
                                        target_size=(IMAGE_HEIGHT,IMAGE_WIDTH),
                                        batch_size=32,
                                        class_mode='categorical', shuffle=False)
# Out:
# Found 9021 images belonging to 3 classes.
# Found 1357 images belonging to 3 classes.
# Found 1357 images belonging to 3 classes.

# %%
samples,features = data.shape
null_values = data.isnull().sum().sum()

print('Basic EDA')
print('Number of samples: %d'%(samples))
print('Number of Null samples: %d' % (null_values))
# Out:
# Basic EDA
# Number of samples: 9048
# Number of Null samples: 0

# %%
import seaborn as sns
#Samples per class
plt.figure(figsize=(20,8))
sns.set(style="ticks", font_scale = 1)
ax = sns.countplot(data = data,x='Labels',order = data['Labels'].value_counts().index,palette="flare")
sns.despine(top=True, right=True, left=True, bottom=False)
plt.xticks(rotation=0,fontsize = 12)
ax.set_xlabel('Sample Type - Diagnosis',fontsize = 14,weight = 'bold')
ax.set(yticklabels=[])
ax.axes.get_yaxis().set_visible(False) 
plt.title('Number of Samples per Class', fontsize = 16,weight = 'bold');
#Plot numbers
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/samples)), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
    ha='center', va='bottom', color='black', xytext=(0, 10),rotation = 'horizontal',
    textcoords='offset points')

# %%
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.layers import *
from keras.models import *
from sklearn.metrics import classification_report, confusion_matrix
from keras.preprocessing import image
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler
from keras.applications.densenet import DenseNet121

import numpy as np # linear algebra
import pandas as pd
annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x)

es = EarlyStopping(monitor='val_acc', mode='max', verbose=1, patience=100)
mc = ModelCheckpoint("own.h5", monitor='val_loss',save_best_only=True, mode='min',verbose=1)

# %%
epochs = 100
stepsperepoch=9
validationsteps=1

# %%
#from keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras.metrics import AUC
from tensorflow.keras.activations import sigmoid
from tensorflow.keras.optimizers import SGD, Adam, Adamax
from tensorflow.keras import Model
import tensorflow as tf

# %%
input_t = Input(shape=(224, 224, 3))

# %%
model = tf.keras.models.Sequential([
      layers.BatchNormalization(),
      layers.Conv2D(64, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(0.3),
      layers.Conv2D(128,3,activation='relu'),
      layers.MaxPooling2D(),
      layers.Conv2D(256, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(0.3),
      layers.Conv2D(512, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(0.2),
      layers.Flatten(),
      layers.Dense(1024, activation='relu'),
      layers.Dropout(0.15),
      layers.Dense(3, activation= 'softmax')
    ])

# %%
model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit_generator(
    train_gen,
    epochs=epochs,
    callbacks=[annealer,mc,es],
    steps_per_epoch=len(train_gen),
    validation_data=val_gen,
    validation_steps = len(val_gen)
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/100
# 282/282 [==============================] - ETA: 0s - loss: 0.5864 - accuracy: 0.7935
# Epoch 1: val_loss did not improve from 0.19753
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 34s 119ms/step - loss: 0.5864 - accuracy: 0.7935 - val_loss: 0.3059 - val_accuracy: 0.8769 - lr: 0.0010
# Epoch 2/100
# 282/282 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8688
# Epoch 2: val_loss did not improve from 0.19753
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 112ms/step - loss: 0.3328 - accuracy: 0.8688 - val_loss: 0.2043 - val_accuracy: 0.9167 - lr: 9.5000e-04
# Epoch 3/100
# 282/282 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9072
# Epoch 3: val_loss improved from 0.19753 to 0.16041, saving model to own.h5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 34s 122ms/step - loss: 0.2445 - accuracy: 0.9072 - val_loss: 0.1604 - val_accuracy: 0.9418 - lr: 9.0250e-04
# Epoch 4/100
# 282/282 [==============================] - ETA: 0s - loss: 0.2244 - accuracy: 0.9216
# Epoch 4: val_loss improved from 0.16041 to 0.13506, saving model to own.h5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 34s 120ms/step - loss: 0.2244 - accuracy: 0.9216 - val_loss: 0.1351 - val_accuracy: 0.9447 - lr: 8.5737e-04
# Epoch 5/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9338
# Epoch 5: val_loss did not improve from 0.13506
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.1812 - accuracy: 0.9338 - val_loss: 0.1384 - val_accuracy: 0.9573 - lr: 8.1451e-04
# Epoch 6/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9472
# Epoch 6: val_loss did not improve from 0.13506
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 115ms/step - loss: 0.1553 - accuracy: 0.9472 - val_loss: 0.1904 - val_accuracy: 0.9455 - lr: 7.7378e-04
# Epoch 7/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9548
# Epoch 7: val_loss improved from 0.13506 to 0.12750, saving model to own.h5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 34s 120ms/step - loss: 0.1452 - accuracy: 0.9548 - val_loss: 0.1275 - val_accuracy: 0.9617 - lr: 7.3509e-04
# Epoch 8/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9584
# Epoch 8: val_loss did not improve from 0.12750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 112ms/step - loss: 0.1312 - accuracy: 0.9584 - val_loss: 0.1533 - val_accuracy: 0.9632 - lr: 6.9834e-04
# Epoch 9/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9622
# Epoch 9: val_loss did not improve from 0.12750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.1111 - accuracy: 0.9622 - val_loss: 0.1821 - val_accuracy: 0.9536 - lr: 6.6342e-04
# Epoch 10/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9629
# Epoch 10: val_loss did not improve from 0.12750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 31s 112ms/step - loss: 0.1162 - accuracy: 0.9629 - val_loss: 0.2230 - val_accuracy: 0.9580 - lr: 6.3025e-04
# Epoch 11/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9680
# Epoch 11: val_loss did not improve from 0.12750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 112ms/step - loss: 0.1179 - accuracy: 0.9680 - val_loss: 0.1446 - val_accuracy: 0.9565 - lr: 5.9874e-04
# Epoch 12/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9713
# Epoch 12: val_loss did not improve from 0.12750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 31s 111ms/step - loss: 0.1008 - accuracy: 0.9713 - val_loss: 0.1470 - val_accuracy: 0.9609 - lr: 5.6880e-04
# Epoch 13/100
# 282/282 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9694
# Epoch 13: val_loss did not improve from 0.12750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 112ms/step - loss: 0.1037 - accuracy: 0.9694 - val_loss: 0.1615 - val_accuracy: 0.9668 - lr: 5.4036e-04
# Epoch 14/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9744
# Epoch 14: val_loss improved from 0.12750 to 0.10428, saving model to own.h5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 33s 118ms/step - loss: 0.0826 - accuracy: 0.9744 - val_loss: 0.1043 - val_accuracy: 0.9646 - lr: 5.1334e-04
# Epoch 15/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9744
# Epoch 15: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 112ms/step - loss: 0.0885 - accuracy: 0.9744 - val_loss: 0.2186 - val_accuracy: 0.9499 - lr: 4.8767e-04
# Epoch 16/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9779
# Epoch 16: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 31s 111ms/step - loss: 0.0756 - accuracy: 0.9779 - val_loss: 0.2140 - val_accuracy: 0.9668 - lr: 4.6329e-04
# Epoch 17/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9787
# Epoch 17: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 31s 111ms/step - loss: 0.0785 - accuracy: 0.9787 - val_loss: 0.1932 - val_accuracy: 0.9676 - lr: 4.4013e-04
# Epoch 18/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9778
# Epoch 18: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 112ms/step - loss: 0.0778 - accuracy: 0.9778 - val_loss: 0.1658 - val_accuracy: 0.9654 - lr: 4.1812e-04
# Epoch 19/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9837
# Epoch 19: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 31s 111ms/step - loss: 0.0602 - accuracy: 0.9837 - val_loss: 0.2307 - val_accuracy: 0.9646 - lr: 3.9721e-04
# Epoch 20/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9819
# Epoch 20: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 112ms/step - loss: 0.0582 - accuracy: 0.9819 - val_loss: 0.2056 - val_accuracy: 0.9646 - lr: 3.7735e-04
# Epoch 21/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9846
# Epoch 21: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 112ms/step - loss: 0.0603 - accuracy: 0.9846 - val_loss: 0.2159 - val_accuracy: 0.9602 - lr: 3.5849e-04
# Epoch 22/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9832
# Epoch 22: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 31s 111ms/step - loss: 0.
100
# 282/282 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9976
# Epoch 67: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.2515 - val_accuracy: 0.9698 - lr: 3.3866e-05
# Epoch 68/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9982
# Epoch 68: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0104 - accuracy: 0.9982 - val_loss: 0.2920 - val_accuracy: 0.9713 - lr: 3.2172e-05
# Epoch 69/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9975
# Epoch 69: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0121 - accuracy: 0.9975 - val_loss: 0.2897 - val_accuracy: 0.9698 - lr: 3.0564e-05
# Epoch 70/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9977
# Epoch 70: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.3262 - val_accuracy: 0.9705 - lr: 2.9035e-05
# Epoch 71/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9980
# Epoch 71: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.3748 - val_accuracy: 0.9735 - lr: 2.7584e-05
# Epoch 72/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9982
# Epoch 72: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.0101 - accuracy: 0.9982 - val_loss: 0.3156 - val_accuracy: 0.9720 - lr: 2.6205e-05
# Epoch 73/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9987
# Epoch 73: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.0081 - accuracy: 0.9987 - val_loss: 0.3608 - val_accuracy: 0.9690 - lr: 2.4894e-05
# Epoch 74/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9979
# Epoch 74: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0119 - accuracy: 0.9979 - val_loss: 0.2872 - val_accuracy: 0.9713 - lr: 2.3650e-05
# Epoch 75/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9979
# Epoch 75: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 0.3067 - val_accuracy: 0.9720 - lr: 2.2467e-05
# Epoch 76/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9978
# Epoch 76: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0090 - accuracy: 0.9978 - val_loss: 0.3265 - val_accuracy: 0.9727 - lr: 2.1344e-05
# Epoch 77/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9978
# Epoch 77: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.0254 - accuracy: 0.9978 - val_loss: 0.2666 - val_accuracy: 0.9705 - lr: 2.0277e-05
# Epoch 78/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9971
# Epoch 78: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.0128 - accuracy: 0.9971 - val_loss: 0.3035 - val_accuracy: 0.9713 - lr: 1.9263e-05
# Epoch 79/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9977
# Epoch 79: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0108 - accuracy: 0.9977 - val_loss: 0.2756 - val_accuracy: 0.9713 - lr: 1.8300e-05
# Epoch 80/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9977
# Epoch 80: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 113ms/step - loss: 0.0109 - accuracy: 0.9977 - val_loss: 0.2936 - val_accuracy: 0.9705 - lr: 1.7385e-05
# Epoch 81/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9989
# Epoch 81: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.3292 - val_accuracy: 0.9735 - lr: 1.6515e-05
# Epoch 82/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9978
# Epoch 82: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.2994 - val_accuracy: 0.9705 - lr: 1.5690e-05
# Epoch 83/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9990
# Epoch 83: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0070 - accuracy: 0.9990 - val_loss: 0.3312 - val_accuracy: 0.9727 - lr: 1.4905e-05
# Epoch 84/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9987
# Epoch 84: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 115ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.3851 - val_accuracy: 0.9735 - lr: 1.4160e-05
# Epoch 85/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9980
# Epoch 85: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0120 - accuracy: 0.9980 - val_loss: 0.2876 - val_accuracy: 0.9735 - lr: 1.3452e-05
# Epoch 86/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9984
# Epoch 86: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 115ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.2981 - val_accuracy: 0.9720 - lr: 1.2779e-05
# Epoch 87/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9983
# Epoch 87: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0098 - accuracy: 0.9983 - val_loss: 0.3087 - val_accuracy: 0.9735 - lr: 1.2140e-05
# Epoch 88/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9982
# Epoch 88: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 115ms/step - loss: 0.0089 - accuracy: 0.9982 - val_loss: 0.3450 - val_accuracy: 0.9727 - lr: 1.1533e-05
# Epoch 89/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9988
# Epoch 89: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0100 - accuracy: 0.9988 - val_loss: 0.3402 - val_accuracy: 0.9727 - lr: 1.0957e-05
# Epoch 90/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9984
# Epoch 90: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.3161 - val_accuracy: 0.9735 - lr: 1.0409e-05
# Epoch 91/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9983
# Epoch 91: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0141 - accuracy: 0.9983 - val_loss: 0.2970 - val_accuracy: 0.9720 - lr: 9.8884e-06
# Epoch 92/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9979
# Epoch 92: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 115ms/step - loss: 0.0122 - accuracy: 0.9979 - val_loss: 0.3075 - val_accuracy: 0.9742 - lr: 9.3939e-06
# Epoch 93/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9982
# Epoch 93: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.3250 - val_accuracy: 0.9727 - lr: 8.9242e-06
# Epoch 94/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9981
# Epoch 94: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 115ms/step - loss: 0.0106 - accuracy: 0.9981 - val_loss: 0.3159 - val_accuracy: 0.9742 - lr: 8.4780e-06
# Epoch 95/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9981
# Epoch 95: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 33s 116ms/step - loss: 0.0123 - accuracy: 0.9981 - val_loss: 0.3086 - val_accuracy: 0.9727 - lr: 8.0541e-06
# Epoch 96/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9984
# Epoch 96: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.3129 - val_accuracy: 0.9727 - lr: 7.6514e-06
# Epoch 97/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9984
# Epoch 97: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0112 - accuracy: 0.9984 - val_loss: 0.3020 - val_accuracy: 0.9720 - lr: 7.2689e-06
# Epoch 98/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9984
# Epoch 98: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.3161 - val_accuracy: 0.9720 - lr: 6.9054e-06
# Epoch 99/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9987
# Epoch 99: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 32s 114ms/step - loss: 0.0110 - accuracy: 0.9987 - val_loss: 0.3166 - val_accuracy: 0.9735 - lr: 6.5601e-06
# Epoch 100/100
# 282/282 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9986
# Epoch 100: val_loss did not improve from 0.10428
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 282/282 [==============================] - 33s 115ms/step - loss: 0.0124 - accuracy: 0.9986 - val_loss: 0.3190 - val_accuracy: 0.9735 - lr: 6.2321e-06

# %%
preds = model.evaluate(val_gen)
print ("Validation Loss = " + str(preds[0]))
print ("Validation Accuracy = " + str(preds[1]))
# Out:
# 43/43 [==============================] - 3s 76ms/step - loss: 0.3190 - accuracy: 0.9735
# Validation Loss = 0.3190130293369293
# Validation Accuracy = 0.9734708666801453

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(["Train_acc","Validation_acc"])
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(["Train_loss","Validation Loss"])
plt.show()

# %%
test_accu = model.evaluate(
test_gen)
print('The testing accuracy is :',test_accu[1]*100, '%')
# Out:
# 43/43 [==============================] - 3s 75ms/step - loss: 0.3190 - accuracy: 0.9735
# The testing accuracy is : 97.34708666801453 %

# %%
from sklearn.metrics import confusion_matrix
plt.rcParams.update({'font.size': 16})
predictions = model.predict(test_gen)
predictions = np.argmax(predictions,axis=1)
predictions[:15]
cm = confusion_matrix(test_gen.classes, predictions)
cm = pd.DataFrame(cm, index = ['0', '1', '2'], columns = ['0', '1', '2'])
cm
class_names = ['COVID','Normal','Viral_Pneumonia']

def plot_confusion_matrix (cm):
    plt.figure(figsize = (10,10))
    sns.heatmap(
        cm, 
        cmap = 'Blues', 
        linecolor = 'black', 
        linewidth = 1, 
        annot = True, 
        fmt = '', 
        xticklabels = class_names, 
        yticklabels = class_names)
    
plot_confusion_matrix(cm)

# %%
#confusion matrx 
y_pred = model.predict_generator(test_gen, steps=len(test_gen), verbose=1)
y_pred = y_pred.argmax(axis=-1)
y_true = test_gen.classes
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
# Out:
#  1/43 [..............................] - ETA: 4s
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# 43/43 [==============================] - 3s 74ms/step

# %%
import seaborn as sns

def plot_confusion_matrix(normalize):
  classes = ['Viral_Pneumonia','Normal','COVID']
  tick_marks = [0.5,1.5,2.0]
  confusion = confusion_matrix(y_true, y_pred, labels=None, sample_weight=None, normalize=None)
  sns.heatmap(confusion,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  #plt.savefig('/content/drive/My Drive/deep learning projects/covid19/keras-covid-19/vgg_chest_confusion.png')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)
# Out:
# Confusion Matrix without Normalization

# %%
#Classification report
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       452
#            1       0.96      0.96      0.96       452
#            2       0.99      1.00      1.00       453
#
#     accuracy                           0.97      1357
#    macro avg       0.97      0.97      0.97      1357
# weighted avg       0.97      0.97      0.97      1357

# %%
#Let's plot ROC & AUC
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
all_labels = ['COVID-19','NORMAL','Viral_Pneumonia']

# %%
# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (8, 6))

def multiclass_roc_auc_score(y_true, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_true)
    y_test = lb.transform(y_true)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(all_labels): # all_labels: no of the labels, for ex. ['cat', 'dog', 'rat']
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

# calling
#true_concat.reset() # resetting generator
# y_pred = model.predict_generator(y_test, verbose = True)
# y_pred = np.argmax(y_pred, axis=1)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
multiclass_roc_auc_score(y_true, y_pred)
# Out:
# 0.980095218305383

# %%
fid = drive.ListFile({'q':"title='Unseen_data.zip'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('Unseen_data.zip')

# %%
# !unzip Unseen_data.zip
# Out:
# Archive:  Unseen_data.zip
# replace Unseen_data/Covid/1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Unseen_data/Covid/1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg
#   inflating: Unseen_data/Covid/1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg
#   inflating: Unseen_data/Covid/1-s2.0-S0929664620300449-gr2_lrg-a.jpg
#   inflating: Unseen_data/Covid/1-s2.0-S0929664620300449-gr2_lrg-b.jpg
#   inflating: Unseen_data/Covid/1-s2.0-S0929664620300449-gr2_lrg-c.jpg
#   inflating: Unseen_data/Covid/1-s2.0-S0929664620300449-gr2_lrg-d.jpg
#   inflating: Unseen_data/Covid/1-s2.0-S1684118220300608-main.pdf-001.jpg
#   inflating: Unseen_data/Covid/1-s2.0-S1684118220300608-main.pdf-002.jpg
#   inflating: Unseen_data/Covid/1-s2.0-S1684118220300682-main.pdf-002-a1.png
#   inflating: Unseen_data/Covid/1-s2.0-S1684118220300682-main.pdf-002-a2.png
#   inflating: Unseen_data/Covid/1-s2.0-S1684118220300682-main.pdf-003-b1.png
#   inflating: Unseen_data/Covid/1-s2.0-S1684118220300682-main.pdf-003-b2.png
#   inflating: Unseen_data/Covid/23E99E2E-447C-46E5-8EB2-D35D12473C39.png
#   inflating: Unseen_data/Covid/2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg
#   inflating: Unseen_data/Covid/31BA3780-2323-493F-8AED-62081B9C383B.jpeg
#   inflating: Unseen_data/Covid/7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg
#   inflating: Unseen_data/Covid/7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg
#   inflating: Unseen_data/Covid/8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg
#   inflating: Unseen_data/Covid/93FE0BB1-022D-4F24-9727-987A07975FFB.jpeg
#   inflating: Unseen_data/Covid/9C34AF49-E589-44D5-92D3-168B3B04E4A6.jpeg
#   inflating: Unseen_data/Normal/Normal-10172.png
#   inflating: Unseen_data/Normal/Normal-10173.png
#   inflating: Unseen_data/Normal/Normal-10174.png
#   inflating: Unseen_data/Normal/Normal-10175.png
#   inflating: Unseen_data/Normal/Normal-10176.png
#   inflating: Unseen_data/Normal/Normal-10177.png
#   inflating: Unseen_data/Normal/Normal-10178.png
#   inflating: Unseen_data/Normal/Normal-10179.png
#   inflating: Unseen_data/Normal/Normal-10180.png
#   inflating: Unseen_data/Normal/Normal-10181.png
#   inflating: Unseen_data/Normal/Normal-10182.png
#   inflating: Unseen_data/Normal/Normal-10183.png
#   inflating: Unseen_data/Normal/Normal-10184.png
#   inflating: Unseen_data/Normal/Normal-10185.png
#   inflating: Unseen_data/Normal/Normal-10186.png
#   inflating: Unseen_data/Normal/Normal-10187.png
#   inflating: Unseen_data/Normal/Normal-10188.png
#   inflating: Unseen_data/Normal/Normal-10189.png
#   inflating: Unseen_data/Normal/Normal-10190.png
#   inflating: Unseen_data/Normal/Normal-10191.png
#   inflating: Unseen_data/Normal/Normal-10192.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-1.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-10.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-11.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-12.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-13.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-14.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-15.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-16.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-17.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-18.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-19.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-2.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-20.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-3.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-4.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-5.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-6.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-7.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-8.png
#   inflating: Unseen_data/Pnemonia/Viral Pneumonia-9.png

# %% [markdown]
# # Normal Test (10 0ut of 9)

# %%
from keras.preprocessing import image

def get_img_array(img_path):
  """
  Input : Takes in image path as input 
  Output : Gives out Pre-Processed image
  """
  path = img_path
  img = image.load_img(path, target_size=(224,224,3))
  img = image.img_to_array(img)
  img = np.expand_dims(img , axis= 0 )
  
  return img

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10192.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10191.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10172.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10173.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10174.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10183.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10179.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10192.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10191.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Normal/Normal-10190.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = COVID-19
#
# The chances of image being Covid is : 100.0 percent
#
# The chances of image being Normal is : 0.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %% [markdown]
# #Pneumonia(out10 of 8 none)

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = '/content/Unseen_data/Pnemonia/Viral Pneumonia-1.png'    # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-10.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-11.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-14.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-13.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-2.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-20.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = COVID-19
#
# The chances of image being Covid is : 100.0 percent
#
# The chances of image being Normal is : 0.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-3.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-4.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Pnemonia/Viral Pneumonia-5.png"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %% [markdown]
# Covid (out of 10, 10 identified )

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/1-s2.0-S0929664620300449-gr2_lrg-a.jpg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %% [markdown]
# #Covid(10,10)

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/1-s2.0-S0929664620300449-gr2_lrg-a.jpg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/1-s2.0-S1684118220300608-main.pdf-001.jpg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = COVID-19
#
# The chances of image being Covid is : 100.0 percent
#
# The chances of image being Normal is : 0.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = COVID-19
#
# The chances of image being Covid is : 100.0 percent
#
# The chances of image being Normal is : 0.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/93FE0BB1-022D-4F24-9727-987A07975FFB.jpeg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = COVID-19
#
# The chances of image being Covid is : 100.0 percent
#
# The chances of image being Normal is : 0.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/31BA3780-2323-493F-8AED-62081B9C383B.jpeg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/31BA3780-2323-493F-8AED-62081B9C383B.jpeg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/Unseen_data/Covid/2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg"     # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = all_labels[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being Covid is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being Normal is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being Viral_Pneumonia is : {model.predict(img)[0][2]*100} percent")
print()

# to display the image  
plt.imshow(img[0]/255, cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# The given X-Ray image is of type = NORMAL
#
# The chances of image being Covid is : 0.0 percent
#
# The chances of image being Normal is : 100.0 percent
#
# The chances of image being Viral_Pneumonia is : 0.0 percent
